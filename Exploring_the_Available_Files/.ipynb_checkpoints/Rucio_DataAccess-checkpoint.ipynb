# %% [markdown]
# # Accessing EIC Data with Rucio
#
# In this notebook we will learn how to find and access ePIC simulation data using **Rucio**, the data management system used by the EIC.
#
# ## What is Rucio?
#
# Rucio is a tool that keeps track of where all the EIC data files are stored across different computing sites around the world (like JLab and BNL). Instead of needing to know exactly where a file lives, you can ask Rucio to find it for you.
#
# Once Rucio tells you where a file is, we use **XRootD** to actually stream or download it — think of Rucio as the catalog and XRootD as the delivery truck.
#
# ## What will we do in this notebook?
#
# 1. Check we can connect to Rucio
# 2. Learn about Data Identifiers (DIDs) — how EIC files are named
# 3. Use metadata tags to find DIS data files
# 4. Stream a file directly and check its contents
# 5. Do a simple analysis with uproot

# %% [markdown]
# ## 1. Check Rucio is Working
#
# First, let's make sure we can connect to Rucio and check who we are logged in as.

# %%
# Check Rucio is available and we can connect
# !rucio whoami
# Out:
# status     : ACTIVE
# email      : eicprod@jlab.org
# account_type : GROUP
# deleted_at : None
# updated_at : 2024-12-18T17:22:11
# account    : eicread
# suspended_at : None
# created_at : 2024-12-18T14:40:56
# >

# %% [markdown]
# You should see output showing you are connected as the `eicread` account. This is a shared read-only account that gives everyone access to public ePIC data.
#
# If you see an error, make sure you are running this notebook inside the eic-shell environment.

# %% [markdown]
# ## 2. Understanding Data Identifiers (DIDs)
#
# Every file or dataset in Rucio has a unique name called a **Data Identifier (DID)**. For ePIC data, DIDs always look like:
#
# ```
# epic:name
# ```
#
# where `epic` is the **scope** (it's always `epic` for our data) and `name` describes what the data is.
#
# For example, a DIS dataset might look like:
#
# ```
# epic:/RECO/26.02.0/epic_craterlake/DIS/NC/18x275/minQ2=10
# ```
#
# Breaking this down:
# - `RECO` — reconstructed data (not raw simulation)
# - `26.02.0` — software release used (February 2026)
# - `epic_craterlake` — detector configuration
# - `DIS/NC` — Deep Inelastic Scattering, Neutral Current
# - `18x275` — 18 GeV electrons on 275 GeV protons
# - `minQ2=10` — minimum Q² of 10 GeV²
#
# > **Note:** Even though the name looks like a file path, it is **not** a directory structure — it is just a flat name.

# %% [markdown]
# ## 3. Finding DIS Data Using Metadata Tags
#
# Rather than guessing DID names, we can search using **metadata tags**. These are labels attached to datasets that describe the physics content.
#
# Useful tags for DIS data:
# - `electron_beam_energy_gev` — electron beam energy
# - `ion_beam_energy_gev` — ion beam energy
# - `q2_min_gev2` — minimum Q²
# - `data_level` — `reconstruction` or `simulation`
# - `software_release` — which software version was used
#
# Let's find DIS datasets with 18 GeV electrons on 275 GeV protons:

# %%
# Find DIS datasets with 18x275 beam energies
# !rucio did list --filter 'electron_beam_energy_gev==18, ion_beam_energy_gev==275' 'epic:*'
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------+--------------+
# | SCOPE:NAME                                                                                                                       | [DID TYPE]   |
# |----------------------------------------------------------------------------------------------------------------------------------+--------------|
# | epic:/RECO/26.04.1/epic_craterlake/DIS/NC/18x275/minQ2=1                                                                         | N/A          |
# | epic:/FULL/main/epic_craterlake/Test/2026-04-06_21-14-00/DIS/NC/18x275/minQ2=1                                                   | N/A          |
# | epic:/RECO/main/epic_craterlake/Test/2026-04-06_21-14-00/DIS/NC/18x275/minQ2=1                                                   | N/A          |
# | epic:/FULL/main/epic_craterlake/Test/2026-04-06_21-31-00/DIS/NC/18x275/minQ2=1                                                   | N/A          |
# | epic:/RECO/main/epic_craterlake/Test/2026-04-06_21-31-00/DIS/NC/18x275/minQ2=1                                                   | N/A          |
# | epic:/FULL/main/epic_craterlake/Test/2026-04-07_07-18-00/DIS/NC/18x275/minQ2=1                                                   | N/A          |
# | epic:/RECO/main/epic_craterlake/Test/2026-04-07_07-18-00/DIS/NC/18x275/minQ2=1                                                   | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/2026-04-07_15-49-05/DIS/NC/18x275/minQ2=1                                                     | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/Backgrounds/2026-04-07_15-49-05/DIS/NC/18x275/minQ2=1                                         | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/2026-04-07_20-36-14/DIS/NC/18x275/minQ2=1                                                     | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/Backgrounds/2026-04-07_20-36-14/DIS/NC/18x275/minQ2=1                                         | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/2026-04-08_14-00-59/DIS/NC/18x275/minQ2=1                                                     | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/Backgrounds/2026-04-08_14-00-59/DIS/NC/18x275/minQ2=1                                         | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DDVCS_ABCONV/EpIC1.1.6-1.0/18x275/q2_0_10/mudecay/hplus                             | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DIS/CC/18x275/minQ2=100                                                                       | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DDVCS_ABCONV/EpIC1.1.6-1.0/18x275/q2_0_10/mudecay/hplus                             | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/CC/18x275/minQ2=100                                                                       | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DIS/NC/18x275/minQ2=10                                                                        | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/CC/18x275/minQ2=1000                                                                      | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/NC/18x275/minQ2=10                                                                        | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/2026-04-28_18-23-31/DIS/NC/18x275/minQ2=1                                                     | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/Backgrounds/2026-04-28_18-23-31/DIS/NC/18x275/minQ2=1                                         | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/SIDIS/D0_ABCONV/pythia8.306-1.0/18x275/hiDiv                                                  | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/NC/18x275/minQ2=100                                                                       | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/PHOTOPRODUCTION_JPSI_ABCONV/coherent_ep/eSTARlight1.3.0-1.0/18x275/q2_nocut/mudecay | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/NC/18x275/minQ2=1000                                                                      | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/SIDIS/pythia6-eic/1.0.0/18x275/q2_0to1                                                        | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/NC/18x275/minQ2=1                                                                         | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/2026-04-28_12-10-36/DIS/NC/18x275/minQ2=1                                                     | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DIFFRACTIVE_JPSI_ABCONV/lAger3.6.1-1.0/18x275/hiAcc                                 | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/PHOTOPRODUCTION_JPSI_ABCONV/coherent_ep/eSTARlight1.3.0-1.0/18x275/q2_nocut/edecay  | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DIS/NC/18x275/minQ2=1000                                                                      | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/Backgrounds/2026-04-28_12-10-36/DIS/NC/18x275/minQ2=1                                         | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/pythia6-eic/1.2.0/ep_noradcor/18x275/q2_0to1                                            | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DVCS_ABCONV/EpIC_v1.1.6-1.2/18x275/q2_1_100                                         | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DVMP/JPsi_MuMu_ABCONV/lAger3.6.1-1.0/18x275/q2_1to50                                | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DIS/NC/18x275/minQ2=100                                                                       | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DVMP/EpIC1.1.6-1.1/unpolarised/18x275/q2_1_1000                                     | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/2026-05-02_16-13-09/DIS/NC/18x275/minQ2=1                                                     | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/MESON_SF_ABCONV/eicMesonSFGen-1.0.0/ep/18x275                                       | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/Backgrounds/2026-05-02_16-13-09/DIS/NC/18x275/minQ2=1                                         | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/2026-05-02_16-52-22/DIS/NC/18x275/minQ2=1                                                     | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/Backgrounds/2026-05-02_16-52-22/DIS/NC/18x275/minQ2=1                                         | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/UPSILON_ABCONV                                                                      | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DIS/CC/18x275/minQ2=1000                                                                      | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/pythia6-eic/1.2.0/ep_noradcor/18x275/q2_1000to100000                                    | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/pythia6-eic/1.2.0/ep_noradcor/18x275/q2_100to1000                                       | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DDVCS_ABCONV/EpIC1.1.6-1.0/18x275/q2_0_10/mudecay/hminus                            | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DDVCS_ABCONV/EpIC1.1.6-1.0/18x275/q2_0_10/edecay/hplus                              | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DDVCS_ABCONV/EpIC1.1.6-1.0/18x275/q2_0_10/mudecay/hminus                            | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DVCS_ABCONV/EpIC_v1.1.6-1.2/18x275/q2_1_100                                         | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/SIDIS/DIJET_ABCONV/pythia6.428-dijet-v1.0/PGF/noRC/ep/18x275/q2_1to20000                      | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/UPSILON_ABCONV                                                                      | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DDVCS_ABCONV/EpIC1.1.6-1.0/18x275/q2_0_10/edecay/hminus                             | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/PHOTOPRODUCTION_JPSI_ABCONV/coherent_ep/eSTARlight1.3.0-1.0/18x275/q2_nocut/mudecay | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/MESON_SF_ABCONV/eicMesonSFGen-1.0.0/ep/18x275                                       | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DIFFRACTIVE_JPSI_ABCONV/lAger3.6.1-1.0/18x275/hiAcc                                 | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DVMP/JPsi_MuMu_ABCONV/lAger3.6.1-1.0/18x275/q2_1to50                                | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/PHOTOPRODUCTION_JPSI_ABCONV/coherent_ep/eSTARlight1.3.0-1.0/18x275/q2_nocut/edecay  | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/pythia6-eic/1.2.0/ep_noradcor/18x275/q2_1to10                                           | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/D0_ABCONV/pythia8.306-1.0/18x275/hiDiv                                                  | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DDVCS_ABCONV/EpIC1.1.6-1.0/18x275/q2_0_10/edecay/hplus                              | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/pythia6-eic/1.2.0/ep_noradcor/18x275/q2_10to100                                         | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DDVCS_ABCONV/EpIC1.1.6-1.0/18x275/q2_0_10/edecay/hminus                             | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/DIJET_ABCONV/pythia6.428-dijet-v1.0/PGF/noRC/ep/18x275/q2_1to20000                      | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/2026-05-13_11-47-23/DIS/NC/18x275/minQ2=1                                                     | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/Backgrounds/2026-05-13_11-47-23/DIS/NC/18x275/minQ2=1                                         | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/2026-05-13_11-47-29/DIS/NC/18x275/minQ2=1                                                     | N/A          |
# | epic:/RECO/main/epic_craterlake/CI/Backgrounds/2026-05-13_11-47-29/DIS/NC/18x275/minQ2=1                                         | N/A          |
# | epic:/RECO/26.05.0/epic_craterlake/DIS/pythia8.316-1.0/NC/noRad/ep/18x275/q2_1to10                                               | N/A          |
# | epic:/RECO/26.05.0/epic_craterlake/DIS/pythia8.316-1.0/NC/noRad/ep/18x275/q2_10to100                                             | N/A          |
# | epic:/RECO/26.05.0/epic_craterlake/DIS/pythia8.316-1.0/NC/noRad/ep/18x275/q2_100to1000                                           | N/A          |
# +----------------------------------------------------------------------------------------------------------------------------------+--------------+
# >

# %%
# We can narrow it down further by adding more filters
# Let's find only reconstructed data from 2026 software releases
# !rucio did list --filter 'electron_beam_energy_gev==18, ion_beam_energy_gev==275, data_level==reconstruction' 'epic:*'
# Out:
# +----------------------------------------------------------------------------------------------------------------------+--------------+
# | SCOPE:NAME                                                                                                           | [DID TYPE]   |
# |----------------------------------------------------------------------------------------------------------------------+--------------|
# | epic:/RECO/26.04.1/epic_craterlake/DIS/NC/10x100/minQ2=10                                                            | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/CC/10x100/minQ2=100                                                           | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/CC/10x100/minQ2=1000                                                          | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DIFFRACTIVE_JPSI_ABCONV/lAger3.6.1-1.0/10x100/hiAcc                     | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/NC/10x100/minQ2=100                                                           | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/SIDIS/pythia6-eic/1.0.0/10x100/q2_0to1                                            | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DIS/CC/10x100/minQ2=100                                                           | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/SIDIS/D0_ABCONV/pythia8.306-1.1/10x100/q2_1/hiDiv                                 | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/SIDIS/D0_ABCONV/pythia8.306-1.1/10x100/q2_100/hiDiv                               | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/NC/10x100/minQ2=1000                                                          | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/pythia6-eic/1.2.0/ep_noradcor/10x100/q2_1000to100000                        | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/pythia6-eic/1.2.0/ep_noradcor/10x100/q2_1to10                               | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DIS/NC/10x100/minQ2=1000                                                          | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/Bkg_Exact1S_2us/GoldCt/10um/SIDIS/D0_ABCONV/pythia8.306-1.1/10x100/q2_100/hiDiv   | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DIS/NC/10x100/minQ2=1                                                             | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/Lc_ABCONV/HFsim-PYTHIA/pythia8.306-1.2/ep/10x100/q2_1to10000/hiDiv          | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/Bkg_Exact1S_2us/GoldCt/10um/DIS/NC/10x100/minQ2=1                                 | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/NC/10x100/minQ2=1                                                             | N/A          |
# | epic:/RECO/26.03.0/epic_craterlake/DIS/NC/10x100/minQ2=10                                                            | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DIS/NC/10x100/minQ2=100                                                           | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/MESON_SF_ABCONV/eicMesonSFGen-1.0.0/ep/10x100                           | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake_without_zdc/SIDIS/Lc_ABCONV/HFsim-BeAGLE/BeAGLE1.03.01-2.0/eAu/10x100/q2_1to10000 | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DIS/CC/10x100/minQ2=1000                                                          | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DIFFRACTIVE_RHO_ABCONV/sartre1.39-1.1/eAu/coherent/bsat/10x100/q2_1to20 | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DVCS_ABCONV/EpIC_v1.1.6-1.2/10x100/q2_1_100                             | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/MESON_SF_ABCONV/eicMesonSFGen-1.0.0/ep/10x100                           | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/SIDIS/Lc_ABCONV/HFsim-PYTHIA/pythia8.306-1.2/ep/10x100/q2_1to10000/hiDiv          | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake_without_zdc/SIDIS/Lc_ABCONV/HFsim-BeAGLE/BeAGLE1.03.01-2.0/eAu/10x100/q2_1to10000 | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/pythia6-eic/1.2.0/ep_noradcor/10x100/q2_100to1000                           | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/DDIS/rapgap3.310-1.0/noRad/ep/10x100                                              | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake_without_zdc/DIS/BeAGLE1.03.02-2.0/eAu/10x100/q2_1to10                             | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake_without_zdc/DIS/BeAGLE1.03.02-2.0/eAu/10x100/q2_10to100                           | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake_without_zdc/SIDIS/D0_ABCONV/HFsim-BeAGLE/BeAGLE1.03.01-2.0/eAu/10x100/q2_1to10000 | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake_without_zdc/DIS/BeAGLE1.03.02-2.0/eAu/10x100/q2_10to100                           | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DIFFRACTIVE_JPSI_ABCONV/lAger3.6.1-1.0/10x100/hiAcc                     | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DIFFRACTIVE_PHI_ABCONV/BeAGLE1.03.02-1.1/eAu/10x100/q2_1to10000         | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/D0_ABCONV/pythia8.306-1.1/10x100/q2_1/hiDiv                                 | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake/EXCLUSIVE/DIFFRACTIVE_PHI_ABCONV/sartre1.39-1.0/eAu/coherent/bsat/10x100          | N/A          |
# | epic:/RECO/26.03.1/epic_craterlake_without_zdc/SIDIS/D0_ABCONV/HFsim-BeAGLE/BeAGLE1.03.01-2.0/eAu/10x100/q2_1to10000 | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake_without_zdc/DIS/BeAGLE1.03.02-2.0/eAu/10x100/q2_1to10                             | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/Bkg_Exact1S_2us/GoldCt/10um/DIS/NC/10x100/minQ2=100                               | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/D0_ABCONV/pythia8.306-1.1/10x100/q2_100/hiDiv                               | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DVCS_ABCONV/EpIC_v1.1.6-1.2/10x100/q2_1_100                             | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/Bkg_Exact1S_2us/GoldCt/10um/DIS/NC/10x100/minQ2=1                                 | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/SIDIS/pythia6-eic/1.2.0/ep_noradcor/10x100/q2_10to100                             | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/Bkg_Exact1S_2us/GoldCt/10um/DIS/NC/10x100/minQ2=10                                | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DIFFRACTIVE_PHI_ABCONV/BeAGLE1.03.02-1.1/eAu/10x100/q2_1to10000         | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DIFFRACTIVE_RHO_ABCONV/sartre1.39-1.1/eAu/coherent/bsat/10x100/q2_1to20 | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/EXCLUSIVE/DIFFRACTIVE_PHI_ABCONV/sartre1.39-1.0/eAu/coherent/bsat/10x100          | N/A          |
# | epic:/RECO/26.05.0/epic_craterlake/DIS/pythia8.316-1.0/NC/noRad/ep/10x100/q2_10to100                                 | N/A          |
# | epic:/RECO/26.04.1/epic_craterlake/Bkg_Exact1S_2us/GoldCt/10um/DIS/NC/10x100/minQ2=1000                              | N/A          |
# | epic:/RECO/26.05.0/epic_craterlake/DIS/pythia8.316-1.0/NC/noRad/ep/10x100/q2_1to10                                   | N/A          |
# | epic:/RECO/26.05.0/epic_craterlake/DIS/pythia8.316-1.0/NC/noRad/ep/10x100/q2_100to1000                               | N/A          |
# +----------------------------------------------------------------------------------------------------------------------+--------------+
# >

# %% [markdown]
# ## 4. Exploring a Dataset
#
# Once we have a DID, we can look inside it to see what files it contains.
#
# Let's pick a DIS dataset and explore it. Replace the DID below with one from your search results above:

# %%
# Set our DID - update this with a result from your search above
did = "epic:/RECO/26.02.0/epic_craterlake/DIS/NC/18x275/minQ2=10"

# List the files in this dataset (--short gives us just the names)
# !rucio did content list --short {did}

# %%
# Find where a file in this dataset is physically stored
# !rucio replica list file --protocols root --pfns --rses isopenaccess {did}

# %% [markdown]
# You should see a URL starting with `root://dtn-eic.jlab.org` — this tells us the file is stored at JLab and gives us the full path we need to stream it.

# %% [markdown]
# ## 5. Streaming a File with XRootD and Uproot
#
# Now we know where our file is, we can stream it directly — no need to download the whole thing first!
#
# We'll use the file path from the `rucio replica list` output above. Update `file_path` below with your path:

# %%
import uproot
import XRootD

# Update this with the path from your rucio replica list output above
file_path = "root://dtn-eic.jlab.org:1094//volatile/eic/EPIC/RECO/26.02.0/epic_craterlake/DIS/NC/18x275/minQ2=10/pythia8NCDIS_18x275_minQ2=10_beamEffects_xAngle=-0.025_hiDiv_1.0000.eicrecon.edm4eic.root"

# Open the file - this streams it, no download needed!
root_file = uproot.open(file_path)
print("File opened successfully!")
print("Contents:", root_file.keys())
# Out:
# File opened successfully!
# Contents: ['events;4', 'events;3', 'podio_metadata;1']

# %%
# Open the events tree and check how many events we have
events = root_file['events']
print(f"Number of events: {events.num_entries}")

# See what branches (data columns) are available
print("\nAvailable branches (first 20):")
for branch in list(events.keys())[:20]:
    print(" -", branch)
# Out:
# Number of events: 410
#
# Available branches (first 20):
#  - B0ECalClusterAssociations
#  - B0ECalClusterAssociations/B0ECalClusterAssociations.weight
#  - _B0ECalClusterAssociations_rec
#  - _B0ECalClusterAssociations_rec/_B0ECalClusterAssociations_rec.index
#  - _B0ECalClusterAssociations_rec/_B0ECalClusterAssociations_rec.collectionID
#  - _B0ECalClusterAssociations_sim
#  - _B0ECalClusterAssociations_sim/_B0ECalClusterAssociations_sim.index
#  - _B0ECalClusterAssociations_sim/_B0ECalClusterAssociations_sim.collectionID
#  - B0ECalClusters
#  - B0ECalClusters/B0ECalClusters.type
#  - B0ECalClusters/B0ECalClusters.energy
#  - B0ECalClusters/B0ECalClusters.energyError
#  - B0ECalClusters/B0ECalClusters.time
#  - B0ECalClusters/B0ECalClusters.timeError
#  - B0ECalClusters/B0ECalClusters.nhits
#  - B0ECalClusters/B0ECalClusters.position.x
#  - B0ECalClusters/B0ECalClusters.position.y
#  - B0ECalClusters/B0ECalClusters.position.z
#  - B0ECalClusters/B0ECalClusters.positionError.xx
#  - B0ECalClusters/B0ECalClusters.positionError.yy

# %% [markdown]
# ## 6. Simple Analysis — Looking at Reconstructed Tracks
#
# Now let's do something simple with the data — look at the reconstructed particle tracks.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Read a small batch of events (first 1000) to keep things fast
# ReconstructedChargedParticles contains the reconstructed tracks
data = events.arrays(
    ["ReconstructedChargedParticles.momentum.x",
     "ReconstructedChargedParticles.momentum.y",
     "ReconstructedChargedParticles.momentum.z",
     "ReconstructedChargedParticles.energy"],
    entry_stop=1000
)

print("Data loaded successfully!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Data loaded successfully!

# %%
# Calculate momentum magnitude for all particles in all events
px = np.concatenate(data["ReconstructedChargedParticles.momentum.x"].to_list())
py = np.concatenate(data["ReconstructedChargedParticles.momentum.y"].to_list())
pz = np.concatenate(data["ReconstructedChargedParticles.momentum.z"].to_list())

p = np.sqrt(px**2 + py**2 + pz**2)

# Plot the momentum distribution
plt.figure(figsize=(8, 5))
plt.hist(p, bins=100, range=(0, 20), color='steelblue', edgecolor='black')
plt.xlabel('Momentum [GeV/c]')
plt.ylabel('Counts')
plt.title('Reconstructed Charged Particle Momentum\n18x275 DIS, NC, minQ²=10')
plt.yscale('log')
plt.tight_layout()
plt.show()

# %%
# Calculate pseudorapidity (eta) — useful for understanding detector coverage
pt = np.sqrt(px**2 + py**2)
theta = np.arctan2(pt, pz)
eta = -np.log(np.tan(theta / 2))

# Remove any infinite values
eta = eta[np.isfinite(eta)]

plt.figure(figsize=(8, 5))
plt.hist(eta, bins=100, range=(-5, 5), color='darkorange', edgecolor='black')
plt.xlabel('Pseudorapidity η')
plt.ylabel('Counts')
plt.title('Reconstructed Charged Particle Pseudorapidity\n18x275 DIS, NC, minQ²=10')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary
#
# In this notebook we have:
#
# - ✅ Connected to Rucio and checked our account
# - ✅ Learned about DIDs and how EIC data is named
# - ✅ Used metadata tags to search for DIS datasets
# - ✅ Found where files are physically stored
# - ✅ Streamed a file using XRootD without downloading it
# - ✅ Done a simple analysis of reconstructed tracks
#
# ## Exercise
#
# Try finding and streaming a DIS dataset with different beam energies, for example 10x100. What differences do you see in the momentum and pseudorapidity distributions?
#
# **Hint:** Use `rucio did list --filter 'electron_beam_energy_gev==10, ion_beam_energy_gev==100, data_level==reconstruction' 'epic:*'` to find it.
